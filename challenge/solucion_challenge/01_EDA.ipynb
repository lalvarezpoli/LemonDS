# %% [markdown]
# ## Exploratory Data Analysis
#
# #### Luis F. Alvarez
#
# Data Science Challenge - Churn customer identification

# %%
import sys
print(sys.executable)

# %%
import pandas as pd

def load_and_setup(path):
    """Carga inicial y casteo de tipos básicos."""
    df = pd.read_csv(path)
    # Ejemplo: Convertir fechas si existen
    # for col in [c for c in df.columns if 'date' in c.lower()]:
    #     df[col] = pd.to_datetime(df[col])
    return df
